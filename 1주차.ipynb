# %%
from IPython.display import Image

# %% [markdown]
# # 고객이란 무엇인가
#
# ---
# - 기존 방법 :
#     20대 남성 판타지 좋아하는 사람들이 우리는 주 고객일거다.. 이런 느낌!
#     - 너무 한정적인거 아닌가?
# ---
# - 고객을 하위 유사한 그룹으로 나누는 마케팅 (주 고객층과 유사한 그룹들을 확인해보기)
#     - 남성 -> 20대 -> 판타지(우주)
#     - 판타지(로멘스) -> 40대 -> 여성
#
#
# - 지리적, 인구 통계적, 가치 행동 기반으로 적용 가능(A/B 테스팅으로 실제로 확인해보기)
#     - 가치 행동 : RFM : 고객이 우리 시스템에서 돈을 얼마나 많이 쓰는지
#                     : 얼마나 자주 들어오는지
#                     : 얼마나 최근에 들어오는지
#
#                 - 예산이 적을때 -> 어떤 타켓팅 부터 할지 확인해보는것
#
#
# - 고객을 이해하고 선택과 집중을 할수 있도록
#     - 해외여행을 하는 사람은 우찌 찾을까?
#     - 고객 행동 분석으로 -> 선점해보기
# ---
#
#
# - 1~ 3정도의 변수를 기준으로 cutoff를 정하여 집단을 나누는 방법

# %% [markdown]
# # 고객은 단일 집단이 아니다

# %%
Image('./image/고객세분화로무엇을.png')

# %% [markdown]
# - 잘못된 고객 분류는 성과로 직결됨
# - 하나의 유니 모델로 타케팅하는 경우 실패 사례 -> 네이버 만화를 전연령대

# %% [markdown]
# # 고객 세분화로 무엇을 얻을수 있는가?
# - 효과적인 캠페인
# ---
# - 고객에 대한 정확한 이해 -> 고객 만족도 향상 -> 더 많은 이익
# ---
# - 고객 니즈 파악 -> 그에 부합하는 상품 개발 기회
#  - 진짜 고객들이 원하는 것은 서칭 결과에 존재한다
# ---
# - 고객 성장 및 확장 유도
#     - 쿠팡에서 4만 8천원 쓰는 손님에게 5만원 쓰면 -> 고객 등급 -> 푸시 알람 등
# ---
# - 매출 증대

# %%
Image('./image/고객세분화대표사례.png')

# %% [markdown]
# # 어떻게 세분화를 할것인가?
# - 데이터 탐색 및 직관 but 논리적
# - 알고리즘 사용 x

# %% [markdown]
# # EDA를 통한 고객 세분화
# - 목적에 맞게 분석가 직관에 따라
# - 세그먼트에 대한 이해가 쉬움
# - 세그먼트 수 및 크기 조절 가능
# - 전략등 짜기 쉬움 (고객 성장 및 확장)

# %% [markdown]
# # EDA를 통한 고객 세분화 단계
# - 세분화 목적 정의 (구매목적, 확장성 등등 목적을 확인하여 변수를)
# - 목적에 맞는 개념 확인
# - 개념을 반영할수 있는 데이터 확인
# - 변수의 분포 확인 후 분활 지점 (Cut-off)정의
# - 각 세그먼트 별 비율 확인
# - 각 세그먼트별 프로파이일

# %% [markdown]
# # 잘 만든 세분화
# - 고객중에 신규 고객은 어떻게 반영해
# - 6개월 동안 안 들어온 고객은 우짬?
#
# - Mutually Exclusive Collectively Exhautive(상호, 베타적, 전체 포괄)
# - 의미가 명확한 세분화
# - 액션 가능한 세분군(최소 개수)
# - 환경 변화에 유지 될수 있는 세분화
#     - "비딩 단가가 변경됨에 따라서 고객 세분화가 유지가 되냐!?"
# - 측정 변수가 단순한 세분화

# %%
Image('./image/가치기반.png')

# %% [markdown]
# # 세분화 종류 - 가치 기반
# - 고객의 행동들이 유지 될 것이다라는 가정
# - 밤에 담배 피는 사람은 내일도 밤에 핀다
# - 현제 고객들을 유지하고 더 올려보자!
# ---
#
# - 기업 입장에 고객 가치를 기준으로 한 세분화
# - 구매력 기반으로 기간 내 실적을 기반으로 정의
# - 현재 또는 과거 구매력과 미래 구매력(LTV)를 교차하여 사용하기도 하며,
#   RFM 등 다양한 축을 반영하여 고객 케어 프로그램등의 우선 순위 차등에 활용
# - 고객 멤버심등으로 공개하여 고객 활동 동기 부여 활용
# - 상위 등급으로 이동 전략 세울수 있음
# - 금적적인 요소 외 비금전적인 요소도 반영(활동력, 전파력, 지속력, 확장성)

# %%
Image('./image/인구통계학적.png')

# %% [markdown]
# # 세분화 종류 - 인구 통계학적
# - 실제로 그 타켓팅이 확실할것이냐?
# - 20대에 확정 하고 가는데 사실은 40대를 더 잘 보는 상황
# - 로멘스를 보는 사람으로 타켓 유저 변경
# - fast하고 easy 하지만..! 잘못하면 굳어질수 잇다
# ---
#
# - 성별, 연령대별 관심사 니즈가 다름
# - 사람을 이해하는 가장 전통적이며 강력한 관점
# - 구매력 (경재력) 및 결혼 유무등 다양한 정보가 밑바닥에 깔려 있음
# - 수집을 못하기에(추청해야 할수도)
# - 너무 큰 범위 , 고정 관념이 작용할수 있음
# - 유사 변수 : 지역, 소득수준,결혼유무, 교육 수준, 종교, 주거 형태등

# %% [markdown]
# # 세분화 종류 - 행동 기반
# - 겹치는 경우가 많음 -> 만화를 좋아하고 골프를 보고 등등 하면 이 사람은 누구냐!
# - 로그 설계 엄청 잘해야함
# ---
#
# - 금적적인 요소 보다 고객의 행동 패턴 및 니즈등 좀 더 근본적인 욕구등을 파악해야함
# - 고객 행동은 지속적으로 유지될 가능성 높으
# - 불편한 점을 해소하거나, 비 금전적인 보상에도 만족도와 충성도를 높일수 잇음
# - 한면의 유저가 여러 행동을 보일수 있음
# - 비즈니스에 로그 설계와 수집 환경에 따라 크게 달라질수잇음
# - 이동정보, 특정 위치 체류기간, 사용시간대, 결재유형, 소비 item 구성
#
# #### 고객은 바뀐다 : 백수였다가 직장이 되었다거나..

# %% [markdown]
# # 세분화 종류 - 가치기반확장(RFM)
# - 2년전 고래 유저 보다 현제 소과금 유저가 중요하다
#
# - RFM 분석
# - 고객의 가치를 평가하거나 또는 고객을 여러 세부군으로 나눠 특성 파악
# - 사용금액과 함께 CRM 관점에서 중요한 비금적이지만 요수를 추가 하여 확장
# - RFM은 Recency, Frequency,Monetary 개의 관점으로 고객의 가치 평가
#     - Frequency : 리텐션!
#     - 고객들을 랭킹을 먹이기도 하지만
#     - 집단 별로 짤라서 확인하고 랭킹을 먹인다
# - 고객의 과거 구매 이력을 바탕으로 유사한 N개의 집단으로 분류하는 방법

# %% [markdown]
# # 세분화 종류 - 가치 기반 확장 (RFM)
# - 4개?
#     - 아예 안쓰는 사람
#     - 조금 쓰는 사람
#     - 적게 쓰는 사람
#     - VIP
#
# - 상위 20프로가 80프로의 구매를 진행할것이다
#
# - 너무 세부적으로 짜르면 큰차이가 없을때도 있다 -> 합치고 합쳐준다

# %% [markdown]
# # 세분화 종류 - 가치 기반 확장 (RFM)
# - Three Metrix
# - Recency (거래의 최근성) : 고객이 얼마나 최근에 구입
# - Frequency (거래 빈도) : 고객이 얼마나 자주 상품을 구입했는가?
# - Monetary (거래 규모) : 괙이 얼마나 많은 금액을 지불한가?
#
# # Grouping Method
# - 분위수 활용 (통계적으로 우선시)
# - 단변수 clustering 활용 (설명력 및 군 집단의 크기 등이 문제 되는 경우가 존재)

# %%
Image('./image/세분화종류-가치기반_RFM.png')

# %% [markdown]
# - 세분화 되면 -> 집단 별로 엑션을 넣을수 있다?

# %% [markdown]
# # RFM 세분화시 주의할점
# - 차원별로 너무 많은 숫자로 나눌 경우 각 세분별 유저수가 너무 작아짐
#     - 주변 집단과 특성상 큰 차이가 없을 수 있다
#     - 각 세분군 별 action을 하기 어려울수 있음
# - 3차원 데이터 실무에 사용하기 어려울수 있음(e단순화 필요)

# %%
Image('./image/RFM세분화_단순화적용사례.png')

# %% [markdown]
# - 기간에 따라서

# %%
Image('./image/RFM세분화_단순화적용사례1.png')

# %% [markdown]
# ### 축을 줄일떄 어떤 데이터를 보고 줄일수 있을까?
#     - 상관관계를 봐서 RFM과 돈과의 상관관계를 확인 (중요하네)

# %%
Image('./image/RFM세분화_단순화적용사례2.png')

# %% [markdown]
# - 다양한 계열사에서 구매를 하기를 원해

# %%
# 통신사 고객 가치 세분화 - pdf 보기 : 기획서를 쓸때 이렇게 써야할듯
# 우리 linkback 데이터를 통해서 해당건에 대한 걸 써서 
# 퍼포먼스 마케팅에서 어떻게 해야하는지 
# 현제 움직이는지 이런걸 말할 수 있는 프로젝트
# 군집분석시 -> 내가 원하는 방식으로 나누기가 어려움
# 데이터를 보고 또 설명을 해야함..!
# 서비스 침투를 -> 카테고리 , 금액상을 변경은 언제나 가능할것 같다!
# hierach clustering으로 유사한거 모아주는것도 케이스지만 (한번 확인하는 프로젝트도!)
# 자동화할려면 근데 이거 최적 알고리즘은 찾아봐야할것 같아!

# 우리가 나눈 부분들을 기반으로 해주면 좋아요!
# clustering 하고 profileing 은 계속 붙여서 간다

## 이탈 세분화
## 고객 상품 세분화!
### 이탈 스쿼어, 다른 카테고리를 살 확률, 언제 살건지? 이런거 
#### DB에 여러가지 세분화를 제공하고 crm에서 쓴다 
#### 우리 db에서 user단으로 세분화를 넣어주고.. progammatic learning

# %% [markdown]
# # Code 풀어보기

# %% [markdown]
# - 이커머스 행동 데이터
# - UK 온오프라인 매장 데이터
# - 고객 세분화를 다루기에 좋은 데이터
# - RFM 만들어 볼거임

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_org = pd.read_csv('./data/1st_data.csv', encoding='latin')

# %%
# 문자열 변수를 datetime 으로 변환 
df_org['InvoiceDate'] = pd.DatetimeIndex(df_org['InvoiceDate'])
df_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # NULL 처리

# %%
# Null 값이 있는 전체 case 수 확인
df_org.isnull().sum().sum()
# Out:
# 136534

# %%
# Null 값의 비율
df_org.isnull().sum().sum() / df_org.shape[0]
# Out:
# 0.2519500506542611

# %%
# Null 값이 있는 변수 확인
df_org.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ### Question
# - CustomerID 가 Null인 경우가 정상일까?
# - 만약 Null 인 경우가 정상이라면 분석에 사용할 수 있을까?

# %%
# CustomerID 가 Null 인 case  확인하기 
df_org[df_org.CustomerID.isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 622    2010-12-01 11:52:00       0.00         NaN  United Kingdom
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom
# 541540 2011-12-09 10:26:00    1714.17         NaN  United Kingdom
#
# [135080 rows x 8 columns]

# %% [markdown]
# # null 처리

# %%
df_na_treat =  df_org.dropna(axis = 0)

# %%
df_na_treat.isnull().sum().sum()
# Out:
# 0

# %%
df_na_treat.shape
# Out:
# (406829, 8)

# %% [markdown]
# # 데이터 탐색 및 이상치 제거

# %%
df_na_treat.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# 이상치 케이스 확인
df_na_treat[(df_na_treat.Quantity == -80995) | (df_na_treat.Quantity == 80995) ]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
# 540422   C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
# 540422 2011-12-09 09:27:00       2.08     16446.0  United Kingdom

# %%
# Quantity 이상치 case 확인
df_na_treat[df_na_treat.Quantity <= 0 ].count()
# Out:
# InvoiceNo      8905
# StockCode      8905
# Description    8905
# Quantity       8905
# InvoiceDate    8905
# UnitPrice      8905
# CustomerID     8905
# Country        8905
# dtype: int64

# %%
# 음수값으로 시작하는 case는 InvocieNo 가 'C' 로 시작 하는 경우와 case 가 동일함 
df_na_treat['InvoiceNo'].str.startswith("C").value_counts()
# Out:
# False    397924
# True       8905
# Name: InvoiceNo, dtype: int64

# %%
df_na_treat[(df_na_treat.Quantity <= 0) & (df_na_treat.InvoiceNo.str.startswith("C"))].shape
# Out:
# (8905, 8)

# %%
# UnitPirce 가 가장 큰 값도 환불 case 임 
df_na_treat[df_na_treat.UnitPrice == 38970]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 222681   C556445         M      Manual        -1 2011-06-10 15:31:00
#
#         UnitPrice  CustomerID         Country
# 222681    38970.0     15098.0  United Kingdom

# %%
df_na_treat[df_na_treat.UnitPrice == 0].head(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 47068     540372     22090              PAPER BUNTING RETROSPOT        24
# 47070     540372     22553               PLASTERS IN TIN SKULLS        24
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 9302   2010-12-05 14:02:00        0.0     12647.0         Germany
# 33576  2010-12-16 14:36:00        0.0     16560.0  United Kingdom
# 40089  2010-12-21 13:45:00        0.0     14911.0            EIRE
# 47068  2011-01-06 16:41:00        0.0     13081.0  United Kingdom
# 47070  2011-01-06 16:41:00        0.0     13081.0  United Kingdom
# 56674  2011-01-13 15:10:00        0.0     15107.0  United Kingdom
# 86789  2011-02-10 13:08:00        0.0     17560.0  United Kingdom
# 130188 2011-03-23 10:25:00        0.0     13239.0  United Kingdom
# 139453 2011-03-30 12:45:00        0.0     13113.0  United Kingdom
# 145208 2011-04-04 14:42:00        0.0     14410.0  United Kingdom

# %% [markdown]
# # EDA

# %%
# 연속형 변수의 대략적인 분포 확인 

df_na_treat.describe()

# 확인 필요한 부분 
## 1. Quantity 음수와 매우 큰수가 있다. 
## 2. 가격의 max 값이 너무 크다 이상치일 가능성이 있다.
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# # quantity

# %%
sns.boxplot(df_na_treat['Quantity'])
plt.xlim(-10,200)
plt.show()
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_na_treat['Quantity'].quantile(q=0.99,  interpolation='nearest')
# Out:
# 120

# %%
sns.distplot(df_na_treat['Quantity'], bins = 10000)
plt.xlim(-10,150)
plt.show()
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# unit price
sns.boxplot(df_na_treat['UnitPrice'])
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UnitPrice'>

# %%
sns.boxplot(df_na_treat['UnitPrice'])
plt.xlim(-10,100)
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (-10.0, 100.0)

# %%
sns.distplot(df_na_treat['UnitPrice'], hist = True, kde = False, rug = False, bins =10000)
plt.xlim(0,500)
plt.show()
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#  어떤 데이터인지 case 확인 
df_na_treat[df_na_treat.UnitPrice >= 1000]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 45622    C540271         M           Manual        -1 2011-01-06 11:51:00
# 73446    C542348         M           Manual        -1 2011-01-27 12:09:00
# 117052   C546325         M           Manual        -1 2011-03-11 10:15:00
# 117053   C546327         M           Manual        -1 2011-03-11 10:18:00
# 117054    546328         M           Manual         1 2011-03-11 10:19:00
# 117055    546329         M           Manual         1 2011-03-11 10:22:00
# 144826    548813         M           Manual         1 2011-04-04 13:03:00
# 144828    548813         M           Manual         1 2011-04-04 13:03:00
# 144829    548820         M           Manual         1 2011-04-04 13:04:00
# 144831   C548830         M           Manual        -1 2011-04-04 13:08:00
# 144833   C548830         M           Manual        -1 2011-04-04 13:08:00
# 144834   C548834         M           Manual        -1 2011-04-04 13:09:00
# 145831    548913         M           Manual         1 2011-04-05 09:45:00
# 145832   C548914         M           Manual        -1 2011-04-05 09:46:00
# 150591   C549452         D         Discount        -1 2011-04-08 14:17:00
# 150615    549468         M           Manual         1 2011-04-08 14:27:00
# 173277   C551685      POST          POSTAGE        -1 2011-05-03 12:51:00
# 173382    551697      POST          POSTAGE         1 2011-05-03 13:46:00
# 173391   C551699         M           Manual        -1 2011-05-03 14:12:00
# 200744   C554154         M           Manual        -1 2011-05-23 11:24:00
# 200745    554155         M           Manual         1 2011-05-23 11:26:00
# 201553    554301         M           Manual         1 2011-05-23 14:46:00
# 201554   C554302         M           Manual        -1 2011-05-23 14:50:00
# 222681   C556445         M           Manual        -1 2011-06-10 15:31:00
# 268027   C560372         M           Manual        -1 2011-07-18 12:26:00
# 268431   C560420         M           Manual        -1 2011-07-18 15:11:00
# 271151   C560647         M           Manual        -1 2011-07-20 11:31:00
# 293842   C562647         M           Manual        -1 2011-08-08 12:56:00
# 297369   C562938         M           Manual        -1 2011-08-10 17:14:00
# 297438    562946         M           Manual         1 2011-08-11 09:38:00
# 342996   C566925         M           Manual        -1 2011-09-15 15:18:00
# 343000    566927         M           Manual         1 2011-09-15 15:20:00
# 374542    569382         M           Manual         1 2011-10-03 16:44:00
# 406404   C571750         M           Manual        -1 2011-10-19 11:16:00
# 406405   C571750         M           Manual        -1 2011-10-19 11:16:00
# 406406    571751         M           Manual         1 2011-10-19 11:18:00
# 406407    571751         M           Manual         1 2011-10-19 11:18:00
# 422351    573077         M           Manual         1 2011-10-27 14:13:00
# 422375   C573079         M           Manual        -2 2011-10-27 14:15:00
# 422376    573080         M           Manual         1 2011-10-27 14:20:00
# 467436    576339       DOT   DOTCOM POSTAGE         1 2011-11-14 15:27:00
# 467437   C576338      CRUK  CRUK Commission        -1 2011-11-14 15:27:00
# 494728    578270       DOT   DOTCOM POSTAGE         1 2011-11-23 13:39:00
# 508459    579196       DOT   DOTCOM POSTAGE         1 2011-11-28 15:54:00
# 528082    580727       DOT   DOTCOM POSTAGE         1 2011-12-05 17:17:00
# 528087   C580726      CRUK  CRUK Commission        -1 2011-12-05 17:17:00
#
#         UnitPrice  CustomerID         Country
# 45622     1126.00     12503.0           Spain
# 73446     1715.85     12539.0           Spain
# 117052    1687.17     14911.0            EIRE
# 117053    1687.17     14911.0            EIRE
# 117054    1687.17     14911.0            EIRE
# 117055    1687.17     14911.0            EIRE
# 144826    2382.92     12744.0       Singapore
# 144828    1252.95     12744.0       Singapore
# 144829    2053.07     12744.0       Singapore
# 144831    2382.92     12744.0       Singapore
# 144833    1252.95     12744.0       Singapore
# 144834    2053.07     12744.0       Singapore
# 145831    1136.30     12669.0          France
# 145832    1136.30     12669.0          France
# 150591    1867.86     17940.0  United Kingdom
# 150615    1867.86     17940.0  United Kingdom
# 173277    8142.75     16029.0  United Kingdom
# 173382    8142.75     16029.0  United Kingdom
# 173391    6930.00     16029.0  United Kingdom
# 200744    1241.98     12757.0        Portugal
# 200745    1241.98     12757.0        Portugal
# 201553    1241.98     12757.0        Portugal
# 201554    1241.98     12757.0        Portugal
# 222681   38970.00     15098.0  United Kingdom
# 268027    4287.63     17448.0  United Kingdom
# 268431    1592.49     15369.0  United Kingdom
# 271151    3060.60     18102.0  United Kingdom
# 293842    3155.95     15502.0  United Kingdom
# 297369    1121.18     14156.0            EIRE
# 297438    2500.00     15581.0  United Kingdom
# 342996    1829.84     12748.0  United Kingdom
# 343000    2033.10     17846.0  United Kingdom
# 374542    3155.95     15502.0  United Kingdom
# 406404    3949.32     12744.0       Singapore
# 406405    2118.74     12744.0       Singapore
# 406406    3949.32     12744.0       Singapore
# 406407    2118.74     12744.0       Singapore
# 422351    4161.06     12536.0          France
# 422375    4161.06     12536.0          France
# 422376    4161.06     12536.0          France
# 467436    1500.36     14096.0  United Kingdom
# 467437    1038.75     14096.0  United Kingdom
# 494728    1270.06     14096.0  United Kingdom
# 508459    1526.76     14096.0  United Kingdom
# 528082    1599.26     14096.0  United Kingdom
# 528087    1100.44     14096.0  United Kingdom

# %%
# 값이 1000 이상인 case 갯수 확인
df_na_treat[df_na_treat.UnitPrice >= 1000].shape
# Out:
# (46, 8)

# %%
#### InvoiceDate

# %%
print(pd.DatetimeIndex(df_na_treat['InvoiceDate']).min())
print(pd.DatetimeIndex(df_na_treat['InvoiceDate']).max())
print(pd.DatetimeIndex(df_na_treat['InvoiceDate']).to_period('D').value_counts().head(20))
# Out:
# 2010-12-01 08:26:00
# 2011-12-09 12:50:00
# 2011-11-06    3434
# 2011-12-05    3398
# 2011-11-23    3332
# 2011-11-10    3194
# 2011-11-20    3112
# 2011-11-17    3034
# 2011-11-14    2964
# 2011-10-30    2907
# 2011-10-06    2870
# 2011-11-22    2862
# 2011-11-28    2789
# 2011-10-10    2783
# 2011-11-16    2772
# 2011-11-13    2757
# 2011-11-29    2736
# 2010-12-05    2724
# 2011-12-06    2654
# 2011-12-08    2599
# 2011-11-04    2571
# 2011-09-22    2505
# Freq: D, Name: InvoiceDate, dtype: int64

# %%
pd.DatetimeIndex(df_na_treat['InvoiceDate']).to_period('M').value_counts()
# Out:
# 2011-11    65598
# 2011-10    50695
# 2011-09    40822
# 2011-05    28908
# 2011-06    27836
# 2011-03    27822
# 2011-08    27662
# 2011-07    27502
# 2010-12    26850
# 2011-04    23198
# 2011-01    21912
# 2011-02    20363
# 2011-12    17661
# Freq: M, Name: InvoiceDate, dtype: int64

# %%
df_na_treat['Country'].value_counts()
# df_na_treat['Country'].value_counts().sum()
# Out:
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     17
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
df_na_treat.groupby(['StockCode','Description']).size().sort_values(ascending=False).head(10)
# Out:
# StockCode  Description
# 85123A     WHITE HANGING HEART T-LIGHT HOLDER    2070
# 22423      REGENCY CAKESTAND 3 TIER              1905
# 85099B     JUMBO BAG RED RETROSPOT               1662
# 84879      ASSORTED COLOUR BIRD ORNAMENT         1418
# 47566      PARTY BUNTING                         1416
# 20725      LUNCH BAG RED RETROSPOT               1358
# 22720      SET OF 3 CAKE TINS PANTRY DESIGN      1232
# POST       POSTAGE                               1196
# 20727      LUNCH BAG  BLACK SKULL.               1126
# 21212      PACK OF 72 RETROSPOT CAKE CASES       1080
# dtype: int64

# %%
df_na_treat.duplicated().sum()
# Out:
# 5225

# %% [markdown]
# ## 4.3 데이터 cleansing
#  1. 환불 제거
#  2. 무료구매인건 제거
#  3. CustomerId NULL 제거
#  4. 중복 데이터 제

# %%
df_outlier_treat = df_na_treat[(df_na_treat.Quantity > 0) & (df_na_treat.UnitPrice != 0) & (~df_na_treat.CustomerID.isnull()) ]
df_outlier_treat = df_outlier_treat[~df_outlier_treat.duplicated()]
df_outlier_treat.shape
# Out:
# (392692, 8)

# %% [markdown]
# ## 4.4 유저단위 스코어링을 위해 데이터 요약
# 1. 구매 건수 계산을 위해 CustomerId, InvoiceNo 별로 요약
#
# ---

# %%
# df_na_treat.groupby(['StockCode','Description']).size().sort_values(ascending=False).head(10)

# temp_frequecy = df_outlier_treat.groupby(['CustomerID']).InvoiceNo.nunique()
temp_frequecy = df_outlier_treat.groupby(['CustomerID']).size()
temp_frequecy.head()
sns.distplot(temp_frequecy)
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# 
temp_frequecy.to_frame()
df_frequecy = temp_frequecy.reset_index().rename(columns = {'index' :'CustomerID'})
df_frequecy.columns = ['CustomerID','frequecy']
df_frequecy
# Out:
#       CustomerID  frequecy
# 0        12346.0         1
# 1        12347.0       182
# 2        12348.0        31
# 3        12349.0        73
# 4        12350.0        17
# ...          ...       ...
# 4333     18280.0        10
# 4334     18281.0         7
# 4335     18282.0        12
# 4336     18283.0       721
# 4337     18287.0        70
#
# [4338 rows x 2 columns]

# %% [markdown]
# # 2. 유저별 구매 금액 생성

# %%
temp = df_outlier_treat[['CustomerID','Quantity','UnitPrice']].copy()
temp['monitery'] = temp['Quantity'] * temp['UnitPrice']
temp_monitery = temp.groupby(['CustomerID']).monitery.sum()
temp_monitery.head()
sns.distplot(temp_monitery)
# Out:
# /home/hyunsuk.jeong/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='monitery', ylabel='Density'>

# %%
df_monitery = temp_monitery.to_frame()
df_monitery = df_monitery.reset_index().rename(columns = {'index' :'CustomerID'})
df_monitery
# Out:
#       CustomerID  monitery
# 0        12346.0  77183.60
# 1        12347.0   4310.00
# 2        12348.0   1797.24
# 3        12349.0   1757.55
# 4        12350.0    334.40
# ...          ...       ...
# 4333     18280.0    180.60
# 4334     18281.0     80.82
# 4335     18282.0    178.05
# 4336     18283.0   2045.53
# 4337     18287.0   1837.28
#
# [4338 rows x 2 columns]

# %% [markdown]
# 3.유저별 최근 거래 생성
#  - 오늘을 2011-12-10일 로 가정

# %%
# pd.DatetimeIndex(df_na_treat['InvoiceDate']).to_period('D') -""
temp2 = df_outlier_treat[['CustomerID','InvoiceDate']].copy()
temp2['today'] ="2011-12-10"

temp2['diff_days'] = (pd.to_datetime(temp2['today']) - pd.to_datetime(temp2['InvoiceDate'])).dt.days
recency = temp2.groupby('CustomerID').diff_days.min()
recency
# Out:
# CustomerID
# 12346.0    325
# 12347.0      2
# 12348.0     75
# 12349.0     18
# 12350.0    310
#           ...
# 18280.0    277
# 18281.0    180
# 18282.0      7
# 18283.0      3
# 18287.0     42
# Name: diff_days, Length: 4338, dtype: int64

# %%
df_recency = recency.to_frame()
df_recency = df_recency.reset_index().rename(columns = {'index' :'CustomerID', 'diff_days' :'recency'})
df_recency
# Out:
#       CustomerID  recency
# 0        12346.0      325
# 1        12347.0        2
# 2        12348.0       75
# 3        12349.0       18
# 4        12350.0      310
# ...          ...      ...
# 4333     18280.0      277
# 4334     18281.0      180
# 4335     18282.0        7
# 4336     18283.0        3
# 4337     18287.0       42
#
# [4338 rows x 2 columns]

# %%
rfm = pd.merge(df_frequecy, df_recency, how = 'inner', on ='CustomerID')

# %%
RFM_data = pd.merge(rfm, df_monitery, how ='inner', on= 'CustomerID')
RFM_data
# Out:
#       CustomerID  frequecy  recency  monitery
# 0        12346.0         1      325  77183.60
# 1        12347.0       182        2   4310.00
# 2        12348.0        31       75   1797.24
# 3        12349.0        73       18   1757.55
# 4        12350.0        17      310    334.40
# ...          ...       ...      ...       ...
# 4333     18280.0        10      277    180.60
# 4334     18281.0         7      180     80.82
# 4335     18282.0        12        7    178.05
# 4336     18283.0       721        3   2045.53
# 4337     18287.0        70       42   1837.28
#
# [4338 rows x 4 columns]

# %%
RFM_data['fre_score'] = pd.qcut(RFM_data['frequecy'],4, labels =[1,2,3,4])
RFM_data['rec_score'] = pd.qcut(RFM_data['recency'],4, labels =[1,2,3,4])
RFM_data['mon_score'] = pd.qcut(RFM_data['monitery'],4, labels =[1,2,3,4])
RFM_data['total_score'] = RFM_data['fre_score'].astype(int) + RFM_data['rec_score'].astype(int) + RFM_data['mon_score'].astype(int)
RFM_data['total_score'].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
RFM_data.head()
# Out:
#    CustomerID  frequecy  recency  monitery fre_score rec_score mon_score  \
# 0     12346.0         1      325  77183.60         1         4         4
# 1     12347.0       182        2   4310.00         4         1         4
# 2     12348.0        31       75   1797.24         2         3         4
# 3     12349.0        73       18   1757.55         3         2         4
# 4     12350.0        17      310    334.40         1         4         2
#
#    total_score
# 0            9
# 1            9
# 2            9
# 3            9
# 4            7

# %%
plt.figure(figsize =(8,8))
sns.heatmap(data = RFM_data[['frequecy','recency','monitery']].corr(),annot= True,
            fmt ='.1%', linewidths =.5, cmap='Blues')
plt.show()

# %%
df_count_pivot = RFM_data[['rec_score', 'mon_score']].value_counts(sort= False,normalize=True).sort_index().to_frame().unstack()
df_count_pivot
# Out:
#                   0
# mon_score         1         2         3         4
# rec_score
# 1          0.024666  0.036192  0.066851  0.126556
# 2          0.047026  0.059244  0.072153  0.068926
# 3          0.059474  0.070078  0.076072  0.042646
# 4          0.118949  0.084371  0.034809  0.011987

# %%
sns.heatmap(df_count_pivot, annot= True, fmt ='.1%', linewidths =.5, cmap='Blues')
# Out:
# <AxesSubplot:xlabel='None-mon_score', ylabel='rec_score'>

# %%
temp2 = df_outlier_treat[['CustomerID','Country']]
temp2.groupby(['CustomerID','Country']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(12346.0, United Kingdom), (12347.0, Iceland), (12348.0, Finland), (12349.0, Italy), (12350.0, Norway), (12352.0, Norway), (12353.0, Bahrain), (12354.0, Spain), (12355.0, Bahrain), (12356.0, Portugal), (12357.0, Switzerland), (12358.0, Austria), (12359.0, Cyprus), (12360.0, Austria), (12361.0, Belgium), (12362.0, Belgium), (12363.0, Unspecified), (12364.0, Belgium), (12365.0, Cyprus), (12367.0, Denmark), (12370.0, Austria), (12370.0, Cyprus), (12371.0, Switzerland), (12372.0, Denmark), (12373.0, Austria), (12374.0, Austria), (12375.0, Finland), (12377.0, Switzerland), (12378.0, Switzerland), (12379.0, Belgium), (12380.0, Belgium), (12381.0, Norway), (12383.0, Belgium), (12384.0, Switzerland), (12386.0, Australia), (12388.0, Australia), (12390.0, Belgium), (12391.0, Cyprus), (12393.0, Australia), (12394.0, Belgium), (12394.0, Denmark), (12395.0, Belgium), (12397.0, Belgium), (12398.0, Switzerland), (12399.0, Belgium), (12401.0, Belgium), (12402.0, Belgium), (12403.0, Denmark), (12405.0, Finland), (12406.0, Denmark), (12407.0, Belgium), (12408.0, Belgium), (12409.0, Switzerland), (12410.0, Switzerland), (12412.0, Denmark), (12413.0, France), (12414.0, Austria), (12415.0, Australia), (12417.0, Belgium), (12417.0, Spain), (12418.0, Switzerland), (12420.0, Cyprus), (12421.0, Spain), (12422.0, Australia), (12422.0, Switzerland), (12423.0, Belgium), (12424.0, Australia), (12425.0, Portugal), (12426.0, Germany), (12427.0, Germany), (12428.0, Finland), (12429.0, Austria), (12429.0, Denmark), (12430.0, Norway), (12431.0, Australia), (12431.0, Belgium), (12432.0, Norway), (12433.0, Norway), (12434.0, Australia), (12435.0, Denmark), (12436.0, Norway), (12437.0, France), (12438.0, Norway), (12441.0, France), (12442.0, Spain), (12444.0, Norway), (12445.0, Spain), (12446.0, RSA), (12447.0, Belgium), (12448.0, Spain), (12449.0, Belgium), (12450.0, Spain), (12451.0, Switzerland), (12452.0, Switzerland), (12453.0, Austria), (12454.0, Spain), (12455.0, Cyprus), (12455.0, Spain), (12456.0, Switzerland), (12457.0, Cyprus), ...]
#
# [4346 rows x 0 columns]

# %%
RFM_data.CustomerID.nunique()
# Out:
# 4338
